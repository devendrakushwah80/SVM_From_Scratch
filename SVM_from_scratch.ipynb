# %%
import numpy as np

# %%
class SVM:
    def __init__(self,learning_rate=0.01, n_iters=1000,lambda_param=0.01):
        self.learning_rate = learning_rate
        self.n_iters = n_iters
        self.lambda_param = lambda_param
        self.weights = None
        self.bias = None
    def fit(self,X,y):
        y_ = np.where(y <= 0, -1, 1)
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0
        for i in range(self.n_iters):
            for j, x_i in enumerate(X):
                condition = y_[j] * (np.dot(x_i, self.weights) - self.bias) >= 1
                if condition:
                    self.weights = self.weights - self.learning_rate * (2 * self.lambda_param * self.weights)
                else:
                    self.weights = self.weights - self.learning_rate * (2 * self.lambda_param * self.weights - np.dot(x_i, y_[j]))
                    self.bias = self.bias - self.learning_rate * y_[j]

    def predict(self,X):    
        y_pred = np.dot(X, self.weights) - self.bias
        return np.sign(y_pred)

# %%
X = np.array([
    [2, 3],     # class +1
    [3, 3],     # class +1
    [1, 1],     # class +1
    [-1, -1],   # class -1
    [-2, -3],   # class -1
    [-3, -2]    # class -1
])
y = np.array([1, 1, 1, 0, 0, 0])

# %%
svm = SVM(learning_rate=0.01, n_iters=1000, lambda_param=0.01)
svm.fit(X, y)

preds = svm.predict(X)
print(preds)
# Out:
# [ 1.  1.  1. -1. -1. -1.]
